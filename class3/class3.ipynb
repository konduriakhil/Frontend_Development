# %% [markdown]
# Class-3
# ==========
#
# Variables in JS
# -----------------
# Variables in JavaScript
#
# What is a variable?
#
# A variable is used to save some value/data
#
# A variable can store or save only one value at a time.
#
# A variable is a container which is used to save a value/data
#
# variables are case sensitive
#
# variables can be in capital case and smallcase and to connect two words use underscore
#
# variable can not start with number and can end with number
#
# variable start with $ and _ are only valid with respect to special keywords
#
# varying/vary/varies => Changing
#
# The value of a variable may change during the program execution
#
# In JavaScript, all the variables are declared by using 'var' or 'let' keyword
#
# const keyword:
# --------------
#
# By using this keyword, we can define the constant variable.
#
# A constant is always a FIXED value. The constant value will never change during program execution.
#
# var x = 100; # number
# var username = 'Akhil'; # string
# var status = true; # boolean
#
# let city = 'Hyderabad';
# let price = '8.8';
#
# const state = 'TS';
#
# variables must be write inside JS
#
# ```html
# <html>
# <head>
# <title>Welcome to JavaScript</title>
#
# </head>
# <body>
#
# document.write(x);
#
# <h1 style="color:red;" onclick="this. style.display='none' ">JavaScript Variables</h1>
# <script>
#
# var x = 100;
#
# var username = "Ram Babburi";
#
# document.write(x);I
# console.log('x') #f12 to access console
# document.write(username);
#
# </script>
# </body>
# </html>
# ```
#
# commenting in JS
# ------------------
#
# Multiline comment - /* -- */
# single line comment - // -- //
#
#
# Declaration or Block of Code
# -------------------------------
#
# Any thing write in between { } is called Declaration or block of code

# %% [markdown]
# ## Declaration or Block of Code
#
# * Any thing write in between { } is called Declaration or block of code
# * It wil group multiple statements into a block or one unit
# * we often use this block of code with if statement, for loop
# ```html
# <html>
# <head>
# <title>Welcome to JavaScript</title>
# </head>
# <body>
#
# <script>
#
# {
# var x = 100;
# }
#
# document.write(x)
#
# </script>
# </body>
# </html>
# ```

# %% [markdown]
# ```html
# <html>
# <head>
# <title>Welcome to JavaScript</title>
# </head>
# <body>
#
# <script>
#
# {
# let x = 100;
# const y = 200;
# }
#
# document.write(x);
#
# </script>
# </body>
# </html>
# ```

# %% [markdown]
# ```html
# <html>
# <head>
# <title>Welcome to JavaScript</title>
# </head>
# <body>
#
# <script>
#
# {
# let x = 100;
# const y = 200;
# }
#
# document.write(x);
#
# </script>
# </body>
# </html>
# ```

# %% [markdown]
# * the variables which are declared with let and const are block scope only.
# * means that, the  variable which are declared using let and const within the block, that we can access outside of the block
# * if we use `var` we can access outside of the block.

# %% [markdown]
# ### invalid scenario
# * without initialization of let and const variables, we can  not access them
#
# ```html
# <html>
# <head>
# <title>Welcome to JavaScript</title>
# </head>
# <body>
#
# <script>
#
# {
# x = 100;
# const x
# let x
# document.write(x)
# }
#
# document.write(x);
#
# </script>
# </body>
# </html>
# ```

# %% [markdown]
# * without initialization of the var variable , we can acess them
#
# ```html
# <html>
# <head>
# <title>Welcome to JavaScript</title>
# </head>
# <body>
#
# <script>
#
# x = 100;
# var x
# document.write(x)
#
#
# document.write(x);
#
# </script>
# </body>
# </html>
# ```
